# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

ano = 2015
eleicoes = f'AR_{ano}_Globais'

path = f'eleicoes\\{eleicoes}.xlsx'

sheet_nacional = f'AR_{ano}_Distrito_Reg.Autónoma' 
df_nac = pd.read_excel(path, sheet_name=sheet_nacional, skiprows = 3, nrows = 21)
df_nac.head()
# Out:
#    código  nome do território   ano  total de concelhos  total de freguesias  \
# 0  990000  Resultados Globais  2015                 308                 3092
# 1   10000              Aveiro  2015                  19                  147
# 2   20000                Beja  2015                  14                   75
# 3   30000               Braga  2015                  14                  347
# 4   40000            Bragança  2015                  12                  226
#
#    total de consulados  inscritos    votos  % votos  brancos  % brancos  \
# 0                  NaN    9439701  5380451    57.00   112666       2.09
# 1                  NaN     653597   368071    56.31     9163       2.49
# 2                  NaN     128926    74485    57.77     1230       1.65
# 3                  NaN     787768   474341    60.21    10708       2.26
# 4                  NaN     147465    69644    47.23     1189       1.71
#
#    nulos  % nulos  mandatos    B.E.  % votantes  mandatos.1  CDS-PP  \
# 0  86473     1.61       230  549878       10.22          19  7536.0
# 1   6130     1.67        16   35327        9.60           1     NaN
# 2   1132     1.52         3    6105        8.20           0     NaN
# 3   6112     1.29        19   41745        8.80           1     NaN
# 4   1408     2.02         3    3858        5.54           0     NaN
#
#    % votantes.1  mandatos.2  CDS-PP.PPM  % votantes.2  mandatos.3      JPP  \
# 0          0.14         0.0      3654.0          0.07         0.0  14204.0
# 1           NaN         NaN         NaN           NaN         NaN    448.0
# 2           NaN         NaN         NaN           NaN         NaN     88.0
# 3           NaN         NaN         NaN           NaN         NaN    637.0
# 4           NaN         NaN         NaN           NaN         NaN    121.0
#
#    % votantes.3  mandatos.4  L/TDA  % votantes.4  mandatos.5    MPT  \
# 0          0.26         0.0  39008          0.72           0  22416
# 1          0.12         0.0   1660          0.45           0   1325
# 2          0.12         0.0    271          0.36           0    248
# 3          0.13         0.0   2333          0.49           0   1604
# 4          0.17         0.0    251          0.36           0    223
#
#    % votantes.5  mandatos.6     NC  % votantes.6  mandatos.7    PAN  \
# 0          0.42           0  18722          0.35           0  74752
# 1          0.36           0   1006          0.27           0   3573
# 2          0.33           0    160          0.21           0    608
# 3          0.34           0    972          0.20           0   3682
# 4          0.32           0    160          0.23           0    386
#
#    % votantes.7  mandatos.8  PCP-PEV  % votantes.8  mandatos.9  PCTP/MRPP  \
# 0          1.39           1   444955          8.27          17      59838
# 1          0.97           0    16038          4.36           0       3280
# 2          0.82           0    18592         24.96           1       1945
# 3          0.78           0    24632          5.19           1       5436
# 4          0.55           0     2136          3.07           0        537
#
#    % votantes.9  mandatos.10    PDR  % votantes.10  mandatos.11    PNR  \
# 0          1.11            0  60998           1.13            0  27141
# 1          0.89            0   4548           1.24            0   1698
# 2          2.61            0    351           0.47            0    275
# 3          1.15            0   7500           1.58            0   1836
# 4          0.77            0    546           0.78            0    190
#
#    % votantes.11  mandatos.12  PPD/PSD  % votantes.12  mandatos.13  \
# 0           0.50            0  81054.0           1.51          5.0
# 1           0.46            0      NaN            NaN          NaN
# 2           0.37            0      NaN            NaN          NaN
# 3           0.39            0      NaN            NaN          NaN
# 4           0.27            0      NaN            NaN          NaN
#
#    PPD/PSD.CDS-PP  % votantes.13  mandatos.14      PPM  % votantes.14  \
# 0       1981459.0          36.83         99.0  14805.0           0.28
# 1        177185.0          48.14         10.0   1292.0           0.35
# 2         14980.0          20.11          1.0    192.0           0.26
# 3        216357.0          45.61         10.0    884.0           0.19
# 4         34408.0          49.41          2.0    229.0           0.33
#
#    mandatos.15  PPV/CDC  % votantes.15  mandatos.16       PS  % votantes.16  \
# 0          0.0   2659.0           0.05          0.0  1742012          32.38
# 1          0.0    785.0           0.21          0.0   102726          27.91
# 2          0.0      NaN            NaN          NaN    27775          37.29
# 3          0.0    993.0           0.21          0.0   146412          30.87
# 4          0.0      NaN            NaN          NaN    23718          34.06
#
#    mandatos.17     PTP  % votantes.17  mandatos.18  PTP-MAS  % votantes.18  \
# 0           85  1748.0           0.03          0.0  20709.0           0.38
# 1            5     NaN            NaN          NaN   1253.0           0.34
# 2            1     NaN            NaN          NaN    193.0           0.26
# 3            7     NaN            NaN          NaN   1620.0           0.34
# 4            1     NaN            NaN          NaN    284.0           0.41
#
#    mandatos.19     PURP  % votantes.19  mandatos.20
# 0          0.0  13764.0           0.26          0.0
# 1          0.0    634.0           0.17          0.0
# 2          0.0    340.0           0.46          0.0
# 3          0.0    878.0           0.19          0.0
# 4          0.0      NaN            NaN          NaN

# %%
sheet_int = f'AR_{ano}_Global' 
df_int = pd.read_excel(path, sheet_name=sheet_int, skiprows = 3, nrows = 5)
df_int.head()
# Out:
#    código              círculo   ano  total de concelhos  total de freguesias  \
# 0  990000   Resultados Globais  2015               308.0               3092.0
# 1  500000  Território Nacional  2015               308.0               3092.0
# 2  600000          Estrangeiro  2015                 NaN                  NaN
# 3  800000               Europa  2015                 NaN                  NaN
# 4  900000       Fora da Europa  2015                 NaN                  NaN
#
#    total de consulados  inscritos    votos  % votos  brancos  % brancos  \
# 0                 23.0    9682553  5408805    55.86   112851       2.09
# 1                  NaN    9439701  5380451    57.00   112666       2.09
# 2                 23.0     242852    28354    11.68      185       0.65
# 3                 12.0      78345    13658    17.43      105       0.77
# 4                 11.0     164507    14696     8.93       80       0.54
#
#    nulos  % nulos  mandatos    B.E.  % votantes  mandatos.1  CDS-PP  \
# 0  89544     1.66       230  550892       10.19          19  7536.0
# 1  86473     1.61       226  549878       10.22          19  7536.0
# 2   3071    10.83         4    1014        3.58           0     NaN
# 3   1492    10.92         2     785        5.75           0     NaN
# 4   1579    10.74         2     229        1.56           0     NaN
#
#    % votantes.1  mandatos.2  CDS-PP.PPM  % votantes.2  mandatos.3    JPP  \
# 0          0.14         0.0      3654.0          0.07         0.0  14285
# 1          0.14         0.0      3654.0          0.07         0.0  14204
# 2           NaN         NaN         NaN           NaN         NaN     81
# 3           NaN         NaN         NaN           NaN         NaN     28
# 4           NaN         NaN         NaN           NaN         NaN     53
#
#    % votantes.3  mandatos.4  L/TDA  % votantes.4  mandatos.5    MPT  \
# 0          0.26           0  39340          0.73           0  22596
# 1          0.26           0  39008          0.72           0  22416
# 2          0.29           0    332          1.17           0    180
# 3          0.21           0    249          1.82           0     82
# 4          0.36           0     83          0.56           0     98
#
#    % votantes.5  mandatos.6     NC  % votantes.6  mandatos.7    PAN  \
# 0          0.42           0  21439          0.40           0  75140
# 1          0.42           0  18722          0.35           0  74752
# 2          0.63           0   2717          9.58           0    388
# 3          0.60           0     86          0.63           0    128
# 4          0.67           0   2631         17.90           0    260
#
#    % votantes.7  mandatos.8  PCP-PEV  % votantes.8  mandatos.9  PCTP/MRPP  \
# 0          1.39           1   445980          8.25          17      59955
# 1          1.39           1   444955          8.27          17      59838
# 2          1.37           0     1025          3.62           0        117
# 3          0.94           0      811          5.94           0         98
# 4          1.77           0      214          1.46           0         19
#
#    % votantes.9  mandatos.10    PDR  % votantes.10  mandatos.11    PNR  \
# 0          1.11            0  61632           1.14            0  27269
# 1          1.11            0  60998           1.13            0  27141
# 2          0.41            0    634           2.24            0    128
# 3          0.72            0    169           1.24            0     45
# 4          0.13            0    465           3.16            0     83
#
#    % votantes.11  mandatos.12  PPD/PSD  % votantes.12  mandatos.13  \
# 0           0.50            0  81054.0           1.50          5.0
# 1           0.50            0  81054.0           1.51          5.0
# 2           0.45            0      NaN            NaN          NaN
# 3           0.33            0      NaN            NaN          NaN
# 4           0.56            0      NaN            NaN          NaN
#
#    PPD/PSD.CDS-PP  % votantes.13  mandatos.14    PPM  % votantes.14  \
# 0         1993921          36.86          102  14897           0.28
# 1         1981459          36.83           99  14805           0.28
# 2           12462          43.95            3     92           0.32
# 3            5340          39.10            1     40           0.29
# 4            7122          48.46            2     52           0.35
#
#    mandatos.15  PPV/CDC  % votantes.15  mandatos.16       PS  % votantes.16  \
# 0            0   2659.0           0.05          0.0  1747685          32.31
# 1            0   2659.0           0.05          0.0  1742012          32.38
# 2            0      NaN            NaN          NaN     5673          20.01
# 3            0      NaN            NaN          NaN     4081          29.88
# 4            0      NaN            NaN          NaN     1592          10.83
#
#    mandatos.17     PTP  % votantes.17  mandatos.18  PTP-MAS  % votantes.18  \
# 0           86  1748.0           0.03          0.0    20749           0.38
# 1           85  1748.0           0.03          0.0    20709           0.38
# 2            1     NaN            NaN          NaN       40           0.14
# 3            1     NaN            NaN          NaN       23           0.17
# 4            0     NaN            NaN          NaN       17           0.12
#
#    mandatos.19   PURP  % votantes.19  mandatos.20
# 0            0  13979           0.26            0
# 1            0  13764           0.26            0
# 2            0    215           0.76            0
# 3            0     96           0.70            0
# 4            0    119           0.81            0

# %%
df_nac.rename(columns={"nome do território": "distrito", "distrito/região autónoma": "distrito", 'círculo':'distrito'}, inplace = True)
df_int.rename(columns={"nome do território": "distrito", "distrito/região autónoma": "distrito", 'círculo':'distrito'}, inplace = True)

df_total = pd.concat([df_nac.loc[(df_nac["código"]!=500000) & (df_nac["código"]!=990000)], 
                      df_int.loc[df_int["código"]==800000],
                      df_int.loc[df_int["código"]==810000], 
                      df_int.loc[df_int["código"]==820000], 
                      df_int.loc[df_int["código"]==900000]])   

df_total

# %%
df_base = pd.concat([df_total.iloc[:,0:2],  df_total.iloc[:,6:9], df_total.iloc[:,13]], axis = 1).reset_index(drop = True)
df_base

# %%
df_partidos = pd.concat([df_total.iloc[:,0:2], df_total.iloc[:,14:], df_total.iloc[:,9:13]], axis = 1).fillna(0)
df_partidos.head()

# %%
import janitor

df_partidos_treat = df_partidos.pivot_longer(
                        index = ['código','distrito']
                        , names_to = ["partido", "drop1", "drop2"]
                        , values_to = ["votos", "% votos", "mandatos"]
                        , names_pattern = ["^brancos|^nulos|[A-Z]", "% brancos|% nulos|% votantes.*", "mandatos.*"]
                    ).drop(columns=['drop1', 'drop2'])
df_partidos_treat

# %%
df_base["eleitores por mandato"] = df_base["inscritos"]/df_base["mandatos"]
df_base.sort_values("eleitores por mandato")

# %%
pd.options.mode.chained_assignment = None
def reduzir(df, tam_circ_comp, min_circ):
    i = 0
    df = df.copy(deep=True)
    df["mandatos"] = df["mandatos"].apply(lambda x: max(x, min_circ))
    while i < tam_circ_comp:
        df["eleitores por mandato"] = df["inscritos"]/df["mandatos"]
        df["atingiu minimo"] = df["mandatos"].apply(lambda x: x == min_circ)
        df.sort_values(["atingiu minimo","eleitores por mandato"], inplace = True, ignore_index=True)
        df["mandatos"][0] -= 1
        i += 1
    return df

df_reduzido = reduzir(df_base, 0, 2)
df_reduzido

# %%
def calcular_desvio(df_votos):
    df_votos_nacional = df_votos[~df_votos.partido.isin(["brancos", "nulos"])].groupby("partido", as_index =False)[['votos', 'mandatos']].sum()
    df_votos_nacional["%votos"] = df_votos_nacional["votos"]/sum(df_votos_nacional["votos"])
    df_votos_nacional["%mandatos"] = df_votos_nacional["mandatos"]/sum(df_votos_nacional["mandatos"])
    df_votos_nacional["desvio"] = abs(df_votos_nacional["%votos"]-df_votos_nacional["%mandatos"])
    soma_dos_desvios = sum(df_votos_nacional["desvio"])
    return df_votos_nacional, soma_dos_desvios

calcular_desvio(df_partidos_treat)

# %%
def metodo_hondt(df_mandatos, df_votos, circ_comp):
    df_hondt = df_votos.iloc[:0,:].copy()

    df_votos = df_votos.copy(deep = True)
    partidos = df_votos["partido"].unique()
    df_votos['mandatos'] = 0
    df_votos['votos_dhondt'] = df_votos['votos']
    
    # Iterate over each district
    for d in df_mandatos.itertuples():
        mandatos_d = d.mandatos
        votos_d = df_votos[df_votos['distrito'] == d.distrito]
        
        mandatos_atribuidos = 0
        while mandatos_atribuidos < mandatos_d:
            max_v = max(votos_d['votos_dhondt'])
            votos_d.loc[votos_d['votos_dhondt']==max_v, 'mandatos'] += 1 
            votos_d.loc[votos_d['votos_dhondt']==max_v, 'votos_dhondt'] = votos_d[votos_d['votos_dhondt']==max_v]['votos']/(votos_d[votos_d['votos_dhondt']==max_v]['mandatos']+1)
            mandatos_atribuidos += 1
        
        df_hondt = pd.concat([df_hondt, votos_d[df_hondt.columns]], ignore_index = True)
        
    df_compensacao = df_hondt.groupby("partido", as_index = False)[['votos', 'mandatos']].sum()
    
    mandatos_atribuidos = 0
    df_compensacao['mandatos_compensacao'] = 0
    while mandatos_atribuidos < circ_comp:
        df_compensacao['votos_dhondt'] = df_compensacao['votos']/(df_compensacao['mandatos']+1)
        max_v = max(df_compensacao['votos_dhondt'])
        df_compensacao.loc[df_compensacao['votos_dhondt']==max_v, 'mandatos'] += 1
        df_compensacao.loc[df_compensacao['votos_dhondt']==max_v, 'mandatos_compensacao'] += 1 
        df_compensacao.loc[df_compensacao['votos_dhondt']==max_v, 'votos_dhondt'] = df_compensacao[df_compensacao['votos_dhondt']==max_v]['votos']/(df_compensacao[df_compensacao['votos_dhondt']==max_v]['mandatos']+1)
        mandatos_atribuidos += 1
    
    df_compensacao['código'] = 999999
    df_compensacao['distrito'] = "Compensação"
    df_compensacao['% votos'] = pd.NA

    df_compensacao = df_compensacao[['código', 'distrito', 'partido', 'votos', '% votos', 'mandatos_compensacao']]
    df_compensacao.rename(inplace = True, columns={"mandatos_compensacao": "mandatos"})

    eleitos_compensacao = df_compensacao.loc[df_compensacao['mandatos']>0, 'partido'].unique()
    df_perdidos = df_hondt.loc[(df_hondt['mandatos']==0)&(~df_hondt['partido'].isin(eleitos_compensacao))]
    
    df_hondt = pd.concat([df_hondt, df_compensacao], ignore_index = True)

    
    return df_hondt, df_perdidos

tamanho_circulo_compensacao = 0
metodo_hondt(df_reduzido, df_partidos_treat, tamanho_circulo_compensacao)

# %%
def simular_eleicao(df_mandatos, df_votos, lista_tamanhos_cc, tamanho_circulo_minimo):
    df_desvios = pd.DataFrame(columns = ['circulo_compensacao', 'desvio_proporcionalidade', 'votos_perdidos'])
    for t in lista_tamanhos_cc:
        df_reduzido = reduzir(df_mandatos, t, tamanho_circulo_minimo)
        df_simulacao, df_perdidos = metodo_hondt(df_mandatos, df_votos, t)
        df_nacional, desvio = calcular_desvio(df_simulacao)
        votos_perdidos = sum(df_perdidos['votos'])
        df_desvios.loc[len(df_desvios)] = [t, desvio, votos_perdidos]
        
    return df_desvios

df_desvios = simular_eleicao(df_base, df_partidos_treat, range(0, 231, 1), 2)
df_desvios

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize = (10, 5)) 

df_desvios.plot(x = 'circulo_compensacao', y = 'desvio_proporcionalidade', ax = ax, title = eleicoes) 
df_desvios.plot(x = 'circulo_compensacao', y = 'votos_perdidos', ax = ax, secondary_y = True) 
fig.savefig(f'plots\\{eleicoes}.jpg')
